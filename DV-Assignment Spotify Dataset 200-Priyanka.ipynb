# %%
# !pip install seaborn
# !pip install pandas

# %%
import seaborn as sns
import pandas as pd
data = pd.read_csv("C:/Users/PRIYANKA B/Downloads/Popular_Spotify_Songs_200.csv", encoding='latin1')
data
# Out:
#                               track_name                artist(s)_name  \
# 0    Seven (feat. Latto) (Explicit Ver.)              Latto, Jung Kook
# 1                                   LALA                   Myke Towers
# 2                                vampire                Olivia Rodrigo
# 3                           Cruel Summer                  Taylor Swift
# 4                         WHERE SHE GOES                     Bad Bunny
# ..                                   ...                           ...
# 195         Have You Ever Seen The Rain?  Creedence Clearwater Revival
# 196                        Es un Secreto                        Plan B
# 197                      POLARIS - Remix    Feid, Mora, Saiko, Quevedo
# 198                                Ditto                      NewJeans
# 199                           Take On Me                          a-ha
#
#      artist_count  released_year  released_month  released_day  \
# ...

# %%
sns.histplot(data=data, x="in_spotify_playlists")
# Out:
# <Axes: xlabel='in_spotify_playlists', ylabel='Count'>

# %%
sns.lineplot(x='artist(s)_name',y='bpm',data=data)
# Out:
# <Axes: xlabel='artist(s)_name', ylabel='bpm'>

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (10, 5))
bpm=data['bpm']
artistname=data['artist(s)_name']
plt.bar(bpm,artistname,color ='Black',width = 0.4)
plt.xlabel("bpm")
plt.ylabel("artist(s)_name")
# Out:
# Text(0, 0.5, 'artist(s)_name')
